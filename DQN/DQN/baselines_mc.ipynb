# %%
import gym
import numpy as np
from stable_baselines3 import PPO

from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN

env = gym.make('MountainCar-v0')

model = PPO(MlpPolicy, env, verbose=0)

def evaluate(model, num_episodes=100):
    """
    Evaluate a RL agent
    :param model: (BaseRLModel object) the RL Agent
    :param num_episodes: (int) number of episodes to evaluate it
    :return: (float) Mean reward for the last num_episodes
    """
    # This function will only work for a single Environment
    env = model.get_env()
    all_episode_rewards = []
    for i in range(num_episodes):
        episode_rewards = []
        done = False
        obs = env.reset()
        score = 0
        while not done:
            # _states are only useful when using LSTM policies
            action, _states = model.predict(obs)
            # here, action, rewards and dones are arrays
            # because we are using vectorized env
            obs, reward, done, info = env.step(action)
            episode_rewards.append(reward)
            score += reward
        episode_rewards.append(score)

    return all_episode_rewards

# mean_reward_before_train = evaluate(model, num_episodes=100)

# %%
import gym

from stable_baselines3 import DQN


model = DQN(
    'MlpPolicy',
    env,
    learning_rate = 4e-3,
    verbose=1,
    batch_size = 128,
    buffer_size = 10_000,
    learning_starts=1000,
    gamma = 0.98,
    target_update_interval=600,
    train_freq=16,
    gradient_steps=8,
    exploration_fraction = 0.2,
    exploration_final_eps = 0.07,
    policy_kwargs={'net_arch': [256, 256]}
    )
model.learn(total_timesteps=150_000)

model.save("dqn_cartpole")

model = DQN.load("dqn_cartpole")

env = gym.make("MountainCar-v0")
obs = env.reset()
def evaluate(model, num_episodes=1000):
    """
    Evaluate a RL agent
    :param model: (BaseRLModel object) the RL Agent
    :param num_episodes: (int) number of episodes to evaluate it
    :return: (float) Mean reward for the last num_episodes
    """
    all_episode_rewards = []
    for i in range(num_episodes):
        done = False
        obs = env.reset()
        score = 0
        while not done:
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, done, info = env.step(action)
            score += reward
        all_episode_rewards.append(score)

    return all_episode_rewards

evaluate(model)
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.24     |
# |    n_updates        | 32076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -98.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 149      |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 32429    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.204    |
# |    n_updates        | 32428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | -98.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 149      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 32807    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.256    |
# |    n_updates        | 32804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.3     |
# |    ep_rew_mean      | -98.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 149      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 33162    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.221    |
# |    n_updates        | 33160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.9     |
# |    ep_rew_mean      | -97.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 149      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 33547    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.244    |
# |    n_updates        | 33544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -97.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 149      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 33928    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.193    |
# |    n_updates        | 33924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -98.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 149      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 34348    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.257    |
# |    n_updates        | 34344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -93.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 149      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 34716    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.245    |
# |    n_updates        | 34712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -93.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 149      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 35111    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.176    |
# |    n_updates        | 35108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -92.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 149      |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 35449    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.179    |
# |    n_updates        | 35448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | -92.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 149      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 35797    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.19     |
# |    n_updates        | 35796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -92.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 149      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 36227    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.185    |
# |    n_updates        | 36224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -92.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 149      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 36606    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.268    |
# |    n_updates        | 36604    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -93.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 149      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 36971    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.224    |
# |    n_updates        | 36968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -92.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 149      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 37329    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.259    |
# |    n_updates        | 37328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -91.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 149      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 37662    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.186    |
# |    n_updates        | 37660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -92.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 149      |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 38107    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.201    |
# |    n_updates        | 38104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -93.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 149      |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 38502    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.309    |
# |    n_updates        | 38500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -92.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 149      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 38825    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.253    |
# |    n_updates        | 38824    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.9     |
# |    ep_rew_mean      | -92.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 149      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 39191    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.231    |
# |    n_updates        | 39188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -93.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 149      |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 39571    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.226    |
# |    n_updates        | 39568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -93      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 149      |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 39924    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.252    |
# |    n_updates        | 39920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -93      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 149      |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 40270    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.232    |
# |    n_updates        | 40268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 149      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 40777    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.292    |
# |    n_updates        | 40776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 149      |
# |    time_elapsed     | 275      |
# |    total_timesteps  | 41154    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.287    |
# |    n_updates        | 41152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -93.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 149      |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 41495    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.27     |
# |    n_updates        | 41492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 149      |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 41966    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.248    |
# |    n_updates        | 41964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 149      |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 42348    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.276    |
# |    n_updates        | 42344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -94.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 149      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 42682    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.199    |
# |    n_updates        | 42680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -94.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 149      |
# |    time_elapsed     | 288      |
# |    total_timesteps  | 43122    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.209    |
# |    n_updates        | 43120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -94.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 149      |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 43446    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.32     |
# |    n_updates        | 43444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -93.6    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 149      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 43808    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.209    |
# |    n_updates        | 43804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -93.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 149      |
# |    time_elapsed     | 295      |
# |    total_timesteps  | 44152    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.182    |
# |    n_updates        | 44148    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -94.6    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 149      |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 44673    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.236    |
# |    n_updates        | 44672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -94.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 149      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 44970    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.276    |
# |    n_updates        | 44968    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -93.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 149      |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 45281    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.281    |
# |    n_updates        | 45280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -92.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 149      |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 45596    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.243    |
# |    n_updates        | 45592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -92.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 149      |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 45937    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.251    |
# |    n_updates        | 45936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -92.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 149      |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 46295    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.213    |
# |    n_updates        | 46292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -92.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 149      |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 46660    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.268    |
# |    n_updates        | 46656    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -92.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 149      |
# |    time_elapsed     | 314      |
# |    total_timesteps  | 47015    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.269    |
# |    n_updates        | 47012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -91.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 149      |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 47344    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.32     |
# |    n_updates        | 47340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -90.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 149      |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 47672    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.357    |
# |    n_updates        | 47668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -91      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 149      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 48030    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.238    |
# |    n_updates        | 48028    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -91.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 149      |
# |    time_elapsed     | 324      |
# |    total_timesteps  | 48400    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.254    |
# |    n_updates        | 48396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -91      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 149      |
# |    time_elapsed     | 326      |
# |    total_timesteps  | 48767    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.352    |
# |    n_updates        | 48764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -91      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 149      |
# |    time_elapsed     | 328      |
# |    total_timesteps  | 49123    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.248    |
# |    n_updates        | 49120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -90.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 149      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 49442    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.252    |
# |    n_updates        | 49440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -89.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 149      |
# |    time_elapsed     | 332      |
# |    total_timesteps  | 49788    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.326    |
# |    n_updates        | 49784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -88.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 149      |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 50134    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.356    |
# |    n_updates        | 50132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -88.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 149      |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 50443    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.282    |
# |    n_updates        | 50440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -87.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 149      |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 50812    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.28     |
# |    n_updates        | 50808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -87.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 149      |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 51176    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.351    |
# |    n_updates        | 51172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.5     |
# |    ep_rew_mean      | -88.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 149      |
# |    time_elapsed     | 345      |
# |    total_timesteps  | 51631    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.211    |
# |    n_updates        | 51628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.8     |
# |    ep_rew_mean      | -87.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 149      |
# |    time_elapsed     | 348      |
# |    total_timesteps  | 52001    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.331    |
# |    n_updates        | 52000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -87.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 149      |
# |    time_elapsed     | 350      |
# |    total_timesteps  | 52335    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.271    |
# |    n_updates        | 52332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -89      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 149      |
# |    time_elapsed     | 353      |
# |    total_timesteps  | 52805    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.359    |
# |    n_updates        | 52804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -89.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 149      |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 53175    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.256    |
# |    n_updates        | 53172    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.9     |
# |    ep_rew_mean      | -87.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 149      |
# |    time_elapsed     | 358      |
# |    total_timesteps  | 53563    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.265    |
# |    n_updates        | 53560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -88.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 149      |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 53948    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.232    |
# |    n_updates        | 53944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -89.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 149      |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 54293    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.284    |
# |    n_updates        | 54292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | -89      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 149      |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 54599    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.292    |
# |    n_updates        | 54596    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | -88.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 149      |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 54916    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.3      |
# |    n_updates        | 54912    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | -89.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 149      |
# |    time_elapsed     | 371      |
# |    total_timesteps  | 55329    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.276    |
# |    n_updates        | 55328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -89.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 149      |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 55678    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.304    |
# |    n_updates        | 55676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -89.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 149      |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 56040    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.268    |
# |    n_updates        | 56036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -90.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 149      |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 56464    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.273    |
# |    n_updates        | 56460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -90.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 149      |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 56815    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.291    |
# |    n_updates        | 56812    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -90      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 148      |
# |    time_elapsed     | 383      |
# |    total_timesteps  | 57134    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.281    |
# |    n_updates        | 57132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -90.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 148      |
# |    time_elapsed     | 386      |
# |    total_timesteps  | 57523    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.31     |
# |    n_updates        | 57520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -89.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 148      |
# |    time_elapsed     | 388      |
# |    total_timesteps  | 57856    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.337    |
# |    n_updates        | 57852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -89.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 148      |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 58205    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.312    |
# |    n_updates        | 58204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -90.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 148      |
# |    time_elapsed     | 393      |
# |    total_timesteps  | 58590    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.301    |
# |    n_updates        | 58588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -90.6    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 148      |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 58944    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.281    |
# |    n_updates        | 58940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -91.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 148      |
# |    time_elapsed     | 398      |
# |    total_timesteps  | 59341    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.305    |
# |    n_updates        | 59340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -91.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 148      |
# |    time_elapsed     | 401      |
# |    total_timesteps  | 59708    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.319    |
# |    n_updates        | 59704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | -91.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 148      |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 60094    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.317    |
# |    n_updates        | 60092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | -91.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 148      |
# |    time_elapsed     | 406      |
# |    total_timesteps  | 60412    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.29     |
# |    n_updates        | 60408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -90.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 148      |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 60786    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.247    |
# |    n_updates        | 60784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -90.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 148      |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 61134    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.319    |
# |    n_updates        | 61132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -90      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 148      |
# |    time_elapsed     | 413      |
# |    total_timesteps  | 61440    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.296    |
# |    n_updates        | 61436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.7     |
# |    ep_rew_mean      | -88.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 148      |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 61771    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.359    |
# |    n_updates        | 61768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.4     |
# |    ep_rew_mean      | -88.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 148      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 62111    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.244    |
# |    n_updates        | 62108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.7     |
# |    ep_rew_mean      | -87.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 148      |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 62436    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.279    |
# |    n_updates        | 62432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | -87.5    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 148      |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 62802    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.284    |
# |    n_updates        | 62800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -87      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 148      |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 63090    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.307    |
# |    n_updates        | 63088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | -87.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 148      |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 63433    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.284    |
# |    n_updates        | 63432    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | -87.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 148      |
# |    time_elapsed     | 429      |
# |    total_timesteps  | 63754    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.339    |
# |    n_updates        | 63752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -86.6    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 148      |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 64087    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.272    |
# |    n_updates        | 64084    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | -86.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 148      |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 64466    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.258    |
# |    n_updates        | 64464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | -87.1    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 148      |
# |    time_elapsed     | 437      |
# |    total_timesteps  | 64846    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.291    |
# |    n_updates        | 64844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 148      |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 65190    |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.265    |
# |    n_updates        | 65188    |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.2     |
# |    ep_rew_mean      | -86.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 129      |
# |    time_elapsed     | 1120     |
# |    total_timesteps  | 145208   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.262    |
# |    n_updates        | 145204   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 129      |
# |    time_elapsed     | 1124     |
# |    total_timesteps  | 145562   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.251    |
# |    n_updates        | 145560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87       |
# |    ep_rew_mean      | -86      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 129      |
# |    time_elapsed     | 1127     |
# |    total_timesteps  | 145859   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.224    |
# |    n_updates        | 145856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.6     |
# |    ep_rew_mean      | -86.6    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 129      |
# |    time_elapsed     | 1130     |
# |    total_timesteps  | 146227   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.199    |
# |    n_updates        | 146224   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | -87      |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 129      |
# |    time_elapsed     | 1133     |
# |    total_timesteps  | 146608   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.249    |
# |    n_updates        | 146604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.7     |
# |    ep_rew_mean      | -86.7    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 129      |
# |    time_elapsed     | 1136     |
# |    total_timesteps  | 146924   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.23     |
# |    n_updates        | 146920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | -86.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 129      |
# |    time_elapsed     | 1139     |
# |    total_timesteps  | 147270   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.231    |
# |    n_updates        | 147268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -85.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 129      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 147601   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.226    |
# |    n_updates        | 147600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 129      |
# |    time_elapsed     | 1145     |
# |    total_timesteps  | 147969   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.226    |
# |    n_updates        | 147968   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.4     |
# |    ep_rew_mean      | -86.4    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 129      |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 148284   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.23     |
# |    n_updates        | 148280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.3     |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 129      |
# |    time_elapsed     | 1151     |
# |    total_timesteps  | 148645   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.276    |
# |    n_updates        | 148644   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -85.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 129      |
# |    time_elapsed     | 1153     |
# |    total_timesteps  | 148959   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.242    |
# |    n_updates        | 148956   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.8     |
# |    ep_rew_mean      | -85.8    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 129      |
# |    time_elapsed     | 1156     |
# |    total_timesteps  | 149311   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.267    |
# |    n_updates        | 149308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.9     |
# |    ep_rew_mean      | -85.9    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 128      |
# |    time_elapsed     | 1160     |
# |    total_timesteps  | 149643   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.236    |
# |    n_updates        | 149640   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.2     |
# |    ep_rew_mean      | -85.2    |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 128      |
# |    time_elapsed     | 1163     |
# |    total_timesteps  | 149991   |
# | train/              |          |
# |    learning_rate    | 0.00063  |
# |    loss             | 0.236    |
# |    n_updates        | 149988   |
# ----------------------------------
# [-72.0,
#  -79.0,
#  -78.0,
#  -64.0,
#  -79.0,
#  -71.0,
#  -73.0,
#  -63.0,
#  -96.0,
#  -64.0,
#  -72.0,
#  -92.0,
#  -86.0,
#  -71.0,
#  -72.0,
#  -75.0,
#  -75.0,
#  -70.0,
#  -73.0,
#  -95.0,
#  -72.0,
#  -78.0,
#  -72.0,
#  -100.0,
#  -75.0,
#  -85.0,
#  -75.0,
#  -91.0,
#  -72.0,
#  -79.0,
#  -64.0,
#  -73.0,
#  -87.0,
#  -113.0,
#  -72.0,
#  -72.0,
#  -90.0,
#  -72.0,
#  -64.0,
#  -86.0,
#  -84.0,
#  -71.0,
#  -63.0,
#  -64.0,
#  -94.0,
#  -84.0,
#  -72.0,
#  -110.0,
#  -134.0,
#  -75.0,
#  -100.0,
#  -77.0,
#  -75.0,
#  -91.0,
#  -79.0,
#  -72.0,
#  -80.0,
#  -78.0,
#  -73.0,
#  -63.0,
#  -75.0,
#  -72.0,
#  -64.0,
#  -76.0,
#  -69.0,
#  -100.0,
#  -72.0,
#  -64.0,
#  -64.0,
#  -73.0,
#  -74.0,
#  -80.0,
#  -75.0,
#  -72.0,
#  -82.0,
#  -86.0,
#  -72.0,
#  -104.0,
#  -98.0,
#  -86.0,
#  -73.0,
#  -87.0,
#  -75.0,
#  -72.0,
#  -75.0,
#  -75.0,
#  -87.0,
#  -64.0,
#  -92.0,
#  -72.0,
#  -91.0,
#  -87.0,
#  -83.0,
#  -79.0,
#  -75.0,
#  -80.0,
#  -64.0,
#  -72.0,
#  -86.0,
#  -72.0,
#  -95.0,
#  -74.0,
#  -73.0,
#  -71.0,
#  -64.0,
#  -75.0,
#  -94.0,
#  -64.0,
#  -91.0,
#  -80.0,
#  -91.0,
#  -63.0,
#  -411.0,
#  -63.0,
#  -98.0,
#  -93.0,
#  -63.0,
#  -64.0,
#  -105.0,
#  -83.0,
#  -73.0,
#  -80.0,
#  -109.0,
#  -64.0,
#  -75.0,
#  -63.0,
#  -99.0,
#  -73.0,
#  -79.0,
#  -90.0,
#  -78.0,
#  -72.0,
#  -81.0,
#  -108.0,
#  -98.0,
#  -72.0,
#  -70.0,
#  -63.0,
#  -64.0,
#  -72.0,
#  -79.0,
#  -78.0,
#  -86.0,
#  -81.0,
#  -96.0,
#  -72.0,
#  -108.0,
#  -75.0,
#  -71.0,
#  -72.0,
#  -81.0,
#  -76.0,
#  -95.0,
#  -113.0,
#  -78.0,
#  -79.0,
#  -97.0,
#  -94.0,
#  -64.0,
#  -64.0,
#  -77.0,
#  -65.0,
#  -79.0,
#  -88.0,
#  -75.0,
#  -64.0,
#  -98.0,
#  -73.0,
#  -74.0,
#  -72.0,
#  -70.0,
#  -106.0,
#  -72.0,
#  -63.0,
#  -72.0,
#  -87.0,
#  -73.0,
#  -72.0,
#  -78.0,
#  -88.0,
#  -79.0,
#  -99.0,
#  -132.0,
#  -90.0,
#  -75.0,
#  -63.0,
#  -72.0,
#  -63.0,
#  -88.0,
#  -72.0,
#  -94.0,
#  -64.0,
#  -118.0,
#  -79.0,
#  -89.0,
#  -76.0,
#  -93.0,
#  -79.0,
#  -81.0,
#  -72.0,
#  -77.0,
#  -72.0,
#  -72.0,
#  -93.0,
#  -89.0,
#  -72.0,
#  -72.0,
#  -78.0,
#  -73.0,
#  -76.0,
#  -72.0,
#  -98.0,
#  -74.0,
#  -72.0,
#  -112.0,
#  -72.0,
#  -79.0,
#  -72.0,
#  -80.0,
#  -83.0,
#  -79.0,
#  -74.0,
#  -81.0,
#  -73.0,
#  -64.0,
#  -75.0,
#  -91.0,
#  -93.0,
#  -96.0,
#  -75.0,
#  -63.0,
#  -79.0,
#  -74.0,
#  -63.0,
#  -75.0,
#  -73.0,
#  -96.0,
#  -100.0,
#  -79.0,
#  -75.0,
#  -109.0,
#  -72.0,
#  -69.0,
#  -76.0,
#  -64.0,
#  -74.0,
#  -80.0,
#  -75.0,
#  -64.0,
#  -62.0,
#  -65.0,
#  -99.0,
#  -102.0,
#  -90.0,
#  -69.0,
#  -72.0,
#  -72.0,
#  -125.0,
#  -99.0,
#  -72.0,
#  -86.0,
#  -92.0,
#  -72.0,
#  -70.0,
#  -72.0,
#  -80.0,
#  -76.0,
#  -77.0,
#  -79.0,
#  -64.0,
#  -90.0,
#  -75.0,
#  -75.0,
#  -78.0,
#  -90.0,
#  -79.0,
#  -79.0,
#  -117.0,
#  -75.0,
#  -79.0,
#  -79.0,
#  -85.0,
#  -72.0,
#  -71.0,
#  -63.0,
#  -64.0,
#  -76.0,
#  -72.0,
#  -94.0,
#  -75.0,
#  -79.0,
#  -92.0,
#  -76.0,
#  -82.0,
#  -99.0,
#  -72.0,
#  -75.0,
#  -74.0,
#  -98.0,
#  -75.0,
#  -80.0,
#  -73.0,
#  -71.0,
#  -72.0,
#  -72.0,
#  -71.0,
#  -63.0,
#  -79.0,
#  -84.0,
#  -72.0,
#  -80.0,
#  -64.0,
#  -79.0,
#  -75.0,
#  -63.0,
#  -75.0,
#  -126.0,
#  -106.0,
#  -87.0,
#  -64.0,
#  -75.0,
#  -81.0,
#  -95.0,
#  -63.0,
#  -64.0,
#  -76.0,
#  -78.0,
#  -75.0,
#  -78.0,
#  -75.0,
#  -75.0,
#  -89.0,
#  -79.0,
#  -105.0,
#  -70.0,
#  -82.0,
#  -86.0,
#  -75.0,
#  -72.0,
#  -123.0,
#  -83.0,
#  -148.0,
#  -62.0,
#  -75.0,
#  -72.0,
#  -73.0,
#  -74.0,
#  -64.0,
#  -72.0,
#  -75.0,
#  -74.0,
#  -97.0,
#  -76.0,
#  -79.0,
#  -73.0,
#  -76.0,
#  -71.0,
#  -73.0,
#  -74.0,
#  -95.0,
#  -63.0,
#  -73.0,
#  -78.0,
#  -72.0,
#  -86.0,
#  -76.0,
#  -75.0,
#  -76.0,
#  -75.0,
#  -78.0,
#  -76.0,
#  -62.0,
#  -71.0,
#  -72.0,
#  -63.0,
#  -64.0,
#  -63.0,
#  -103.0,
#  -72.0,
#  -72.0,
#  -79.0,
#  -75.0,
#  -111.0,
#  -79.0,
#  -98.0,
#  -92.0,
#  -72.0,
#  -72.0,
#  -63.0,
#  -75.0,
#  -79.0,
#  -75.0,
#  -99.0,
#  -75.0,
#  -87.0,
#  -72.0,
#  -75.0,
#  -75.0,
#  -72.0,
#  -72.0,
#  -136.0,
#  -96.0,
#  -75.0,
#  -86.0,
#  -74.0,
#  -72.0,
#  -75.0,
#  -64.0,
#  -97.0,
#  -91.0,
#  -62.0,
#  -100.0,
#  -75.0,
#  -75.0,
#  -85.0,
#  -79.0,
#  -64.0,
#  -79.0,
#  -119.0,
#  -94.0,
#  -78.0,
#  -71.0]
